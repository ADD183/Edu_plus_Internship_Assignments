# %%
#Set-1 Question_1
print("Set1_Question1:")
Set1_Q1_a=float(input("Enter 1st Number:"))
print("First input:",Set1_Q1_a)
Set1_Q1_b=float(input("Enter 2nd Number:"))
print("Second input:",Set1_Q1_b)

int_a=int(Set1_Q1_a)
int_b=int(Set1_Q1_b)
print("Sum of intergers is: ",int_a+int_b)
print("Multiplication of integers is: ",int_a*int_b)
# Out:
# Set1_Question1:
# First input: 5.9
# Second input: 10.7
# Sum of intergers is:  15
# Multiplication of integers is:  50

# %%
#Set_1 Question_2

Set1_Q2=[ 9,5,3,14,6,7,12,11,16,10 ]

print("Set1_Question2:")
#a
print("\na)")
print(" First Element: ",Set1_Q2[0])
print(" 5th Element:", Set1_Q2[4])
print(" Last Element:", Set1_Q2[-1])

#b
print("\nb)")
print("Before changing 3rd element:",Set1_Q2)
Set1_Q2[2]=99
print("After changing 3rd element:",Set1_Q2)

#c
print("\nc)")
Set1_Q2.append(200)
print("After Appending 200:",Set1_Q2)

#d
print("\nd)")
popped=Set1_Q2.pop(1)
print(f"{popped} is at 2nd position and it is deleted")
print("After Deleting 2nd Element:",Set1_Q2)
# Out:
# Set1_Question2:
#
# a)
#  First Element:  9
#  5th Element: 6
#  Last Element: 10
#
# b)
# Before changing 3rd element: [9, 5, 3, 14, 6, 7, 12, 11, 16, 10]
# After changing 3rd element: [9, 5, 99, 14, 6, 7, 12, 11, 16, 10]
#
# c)
# After Appending 200: [9, 5, 99, 14, 6, 7, 12, 11, 16, 10, 200]
#
# d)
# 5 is at 2nd position and it is deleted
# After Deleting 2nd Element: [9, 99, 14, 6, 7, 12, 11, 16, 10, 200]

# %%
#Set_1 Question_3
print("Set1_Question3:")
print("Print all even numbers between 1 and 20:")
Set1_Q3=1
while Set1_Q3<20:
    if Set1_Q3%2 == 0:
        print(Set1_Q3)
    Set1_Q3+=1
# Out:
# Set1_Question3:
# Print all even numbers between 1 and 20:
# 2
# 4
# 6
# 8
# 10
# 12
# 14
# 16
# 18

# %%
#Set1_Question4
print("Set1_Question4:")
x = 10   # Global variable

def show():
    x = 20   # Local variable
    print("Local x:", x)
show()
print("Global x:",  x)
# Out:
# Set1_Question4:
# Local x: 20
# Global x: 10

# %%
#Set1_Question5

def greet(a):
    def name(b):
        print(f"Hello {b}, Welcome to {a} World!!")
    return name

print("Set1_Question5:")
call=greet("Python")
call("Aryan")
# Out:
# Hello Aryan, welcome to Python World!!
